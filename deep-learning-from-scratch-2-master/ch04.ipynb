# %%
class Embedding:
    def __init__(self, W):
        self.params = [W]
        self.grads = [np.zeros_like(W)]
        self.idx = None

    def forward(self, idx):
        W, = self.params
        self.idx = idx
        out = W[idx]
        return out

    def backward(self, dout):
        dW, = self.grads
        dW[...] = 0
        np.add.at(dW, self.idx, dout)
        return None

# %%
# coding: utf-8
import sys
sys.path.append('..')
from common.np import *  # import numpy as np
from common.layers import Embedding, SigmoidWithLoss
import collections


class EmbeddingDot:
    def __init__(self, W):
        self.embed = Embedding(W)
        self.params = self.embed.params
        self.grads = self.embed.grads
        self.cache = None

    def forward(self, h, idx):
        target_W = self.embed.forward(idx)
        out = np.sum(target_W * h, axis=1)

        self.cache = (h, target_W)
        return out

    def backward(self, dout):
        h, target_W = self.cache
        dout = dout.reshape(dout.shape[0], 1)

        dtarget_W = dout * h
        self.embed.backward(dtarget_W)
        dh = dout * target_W
        return dh

# %%
class UnigramSampler:
    def __init__(self, corpus, power, sample_size):
        self.sample_size = sample_size
        self.vocab_size = None
        self.word_p = None

        counts = collections.Counter()
        for word_id in corpus:
            counts[word_id] += 1

        vocab_size = len(counts)
        self.vocab_size = vocab_size

        self.word_p = np.zeros(vocab_size)
        for i in range(vocab_size):
            self.word_p[i] = counts[i]

        self.word_p = np.power(self.word_p, power) #power = 0.75
        self.word_p /= np.sum(self.word_p)

    def get_negative_sample(self, target):
        batch_size = target.shape[0]

        if not GPU:
            negative_sample = np.zeros((batch_size, self.sample_size), dtype=np.int32)

            for i in range(batch_size):
                p = self.word_p.copy()
                target_idx = target[i]
                p[target_idx] = 0
                p /= p.sum()
                negative_sample[i, :] = np.random.choice(self.vocab_size, size=self.sample_size, replace=False, p=p)
        else:
            # GPU(cupy）로 계산할 때는 속도를 우선한다.
            # 부정적 예에 타깃이 포함될 수 있다.
            negative_sample = np.random.choice(self.vocab_size, size=(batch_size, self.sample_size),
                                               replace=True, p=self.word_p)

        return negative_sample

# %%
class NegativeSamplingLoss:
    def __init__(self, W, corpus, power=0.75, sample_size=5):
        self.sample_size = sample_size
        self.sampler = UnigramSampler(corpus, power, sample_size)
        self.loss_layers = [SigmoidWithLoss() for _ in range(sample_size + 1)]
        self.embed_dot_layers = [EmbeddingDot(W) for _ in range(sample_size + 1)]

        self.params, self.grads = [], []
        for layer in self.embed_dot_layers:
            self.params += layer.params
            self.grads += layer.grads

    def forward(self, h, target):
        batch_size = target.shape[0]
        negative_sample = self.sampler.get_negative_sample(target)

        # 긍정적 예 순전파
        score = self.embed_dot_layers[0].forward(h, target)
        correct_label = np.ones(batch_size, dtype=np.int32)
        loss = self.loss_layers[0].forward(score, correct_label)

        # 부정적 예 순전파
        negative_label = np.zeros(batch_size, dtype=np.int32)
        for i in range(self.sample_size):
            negative_target = negative_sample[:, i]
            score = self.embed_dot_layers[1 + i].forward(h, negative_target)
            loss += self.loss_layers[1 + i].forward(score, negative_label)

        return loss

    def backward(self, dout=1):
        dh = 0
        for l0, l1 in zip(self.loss_layers, self.embed_dot_layers):
            dscore = l0.backward(dout)
            dh += l1.backward(dscore)

        return dh

# %%
# coding: utf-8
import sys
sys.path.append('..')
from common.np import *  # import numpy as np
from common.layers import Embedding
from ch04.negative_sampling_layer import NegativeSamplingLoss


class CBOW:
    def __init__(self, vocab_size, hidden_size, window_size, corpus):
        V, H = vocab_size, hidden_size

        # 가중치 초기화
        W_in = 0.01 * np.random.randn(V, H).astype('f')
        W_out = 0.01 * np.random.randn(V, H).astype('f')

        # 계층 생성
        self.in_layers = []
        for i in range(2 * window_size):
            layer = Embedding(W_in)  # Embedding 계층 사용
            self.in_layers.append(layer)
        self.ns_loss = NegativeSamplingLoss(W_out, corpus, power=0.75, sample_size=5)

        # 모든 가중치와 기울기를 배열에 모은다.
        layers = self.in_layers + [self.ns_loss]
        self.params, self.grads = [], []
        for layer in layers:
            self.params += layer.params
            self.grads += layer.grads

        # 인스턴스 변수에 단어의 분산 표현을 저장한다.
        self.word_vecs = W_in

    def forward(self, contexts, target):
        h = 0
        for i, layer in enumerate(self.in_layers):
            h += layer.forward(contexts[:, i])
        h *= 1 / len(self.in_layers)
        loss = self.ns_loss.forward(h, target)
        return loss

    def backward(self, dout=1):
        dout = self.ns_loss.backward(dout)
        dout *= 1 / len(self.in_layers)
        for layer in self.in_layers:
            layer.backward(dout)
        return None

# %%
# coding: utf-8
import sys
sys.path.append('..')
import numpy as np
from common import config
# GPU에서 실행하려면 아래 주석을 해제하세요(CuPy 필요).
# ===============================================
# config.GPU = True
# ===============================================
import pickle
from common.trainer import Trainer
from common.optimizer import Adam
from ch04.cbow import CBOW
from ch04.skip_gram import SkipGram
from common.util import create_contexts_target, to_cpu, to_gpu
from dataset import ptb


# 하이퍼파라미터 설정
window_size = 5
hidden_size = 100
batch_size = 100
max_epoch = 10

# 데이터 읽기
corpus, word_to_id, id_to_word = ptb.load_data('train')
vocab_size = len(word_to_id)

contexts, target = create_contexts_target(corpus, window_size)
if config.GPU:
    contexts, target = to_gpu(contexts), to_gpu(target)

# 모델 등 생성
model = CBOW(vocab_size, hidden_size, window_size, corpus)
# model = SkipGram(vocab_size, hidden_size, window_size, corpus)
optimizer = Adam()
trainer = Trainer(model, optimizer)

# 학습 시작
trainer.fit(contexts, target, max_epoch, batch_size)
trainer.plot()

# 나중에 사용할 수 있도록 필요한 데이터 저장
word_vecs = model.word_vecs
if config.GPU:
    word_vecs = to_cpu(word_vecs)
params = {}
params['word_vecs'] = word_vecs.astype(np.float16)
params['word_to_id'] = word_to_id
params['id_to_word'] = id_to_word
pkl_file = 'cbow_params.pkl'  # or 'skipgram_params.pkl'
with open(pkl_file, 'wb') as f:
    pickle.dump(params, f, -1)
# Out:
# | 에폭 1 |  반복 1 / 9295 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 21 / 9295 | 시간 2[s] | 손실 4.16
# | 에폭 1 |  반복 41 / 9295 | 시간 4[s] | 손실 4.15
# | 에폭 1 |  반복 61 / 9295 | 시간 7[s] | 손실 4.12
# | 에폭 1 |  반복 81 / 9295 | 시간 9[s] | 손실 4.05
# | 에폭 1 |  반복 101 / 9295 | 시간 11[s] | 손실 3.93
# | 에폭 1 |  반복 121 / 9295 | 시간 14[s] | 손실 3.77
# | 에폭 1 |  반복 141 / 9295 | 시간 16[s] | 손실 3.61
# | 에폭 1 |  반복 161 / 9295 | 시간 18[s] | 손실 3.50
# | 에폭 1 |  반복 181 / 9295 | 시간 21[s] | 손실 3.36
# | 에폭 1 |  반복 201 / 9295 | 시간 23[s] | 손실 3.24
# | 에폭 1 |  반복 221 / 9295 | 시간 25[s] | 손실 3.16
# | 에폭 1 |  반복 241 / 9295 | 시간 27[s] | 손실 3.07
# | 에폭 1 |  반복 261 / 9295 | 시간 30[s] | 손실 2.99
# | 에폭 1 |  반복 281 / 9295 | 시간 32[s] | 손실 2.93
# | 에폭 1 |  반복 301 / 9295 | 시간 34[s] | 손실 2.92
# | 에폭 1 |  반복 321 / 9295 | 시간 37[s] | 손실 2.88
# | 에폭 1 |  반복 341 / 9295 | 시간 39[s] | 손실 2.84
# | 에폭 1 |  반복 361 / 9295 | 시간 41[s] | 손실 2.81
# | 에폭 1 |  반복 381 / 9295 | 시간 44[s] | 손실 2.81
# | 에폭 1 |  반복 401 / 9295 | 시간 46[s] | 손실 2.76
# | 에폭 1 |  반복 421 / 9295 | 시간 48[s] | 손실 2.72
# | 에폭 1 |  반복 441 / 9295 | 시간 50[s] | 손실 2.73
# | 에폭 1 |  반복 461 / 9295 | 시간 53[s] | 손실 2.71
# | 에폭 1 |  반복 481 / 9295 | 시간 55[s] | 손실 2.69
# | 에폭 1 |  반복 501 / 9295 | 시간 57[s] | 손실 2.70
# | 에폭 1 |  반복 521 / 9295 | 시간 60[s] | 손실 2.69
# | 에폭 1 |  반복 541 / 9295 | 시간 62[s] | 손실 2.66
# | 에폭 1 |  반복 561 / 9295 | 시간 64[s] | 손실 2.67
# | 에폭 1 |  반복 581 / 9295 | 시간 67[s] | 손실 2.66
# | 에폭 1 |  반복 601 / 9295 | 시간 69[s] | 손실 2.64
# | 에폭 1 |  반복 621 / 9295 | 시간 71[s] | 손실 2.65
# | 에폭 1 |  반복 641 / 9295 | 시간 74[s] | 손실 2.62
# | 에폭 1 |  반복 661 / 9295 | 시간 76[s] | 손실 2.63
# | 에폭 1 |  반복 681 / 9295 | 시간 78[s] | 손실 2.59
# | 에폭 1 |  반복 701 / 9295 | 시간 81[s] | 손실 2.63
# | 에폭 1 |  반복 721 / 9295 | 시간 83[s] | 손실 2.59
# | 에폭 1 |  반복 741 / 9295 | 시간 85[s] | 손실 2.60
# | 에폭 1 |  반복 761 / 9295 | 시간 87[s] | 손실 2.57
# | 에폭 1 |  반복 781 / 9295 | 시간 90[s] | 손실 2.59
# | 에폭 1 |  반복 801 / 9295 | 시간 92[s] | 손실 2.57
# | 에폭 1 |  반복 821 / 9295 | 시간 94[s] | 손실 2.60
# | 에폭 1 |  반복 841 / 9295 | 시간 97[s] | 손실 2.59
# | 에폭 1 |  반복 861 / 9295 | 시간 99[s] | 손실 2.56
# | 에폭 1 |  반복 881 / 9295 | 시간 101[s] | 손실 2.58
# | 에폭 1 |  반복 901 / 9295 | 시간 103[s] | 손실 2.56
# | 에폭 1 |  반복 921 / 9295 | 시간 106[s] | 손실 2.59
# | 에폭 1 |  반복 941 / 9295 | 시간 108[s] | 손실 2.55
# | 에폭 1 |  반복 961 / 9295 | 시간 110[s] | 손실 2.58
# | 에폭 1 |  반복 981 / 9295 | 시간 113[s] | 손실 2.53
# | 에폭 1 |  반복 1001 / 9295 | 시간 115[s] | 손실 2.55
# | 에폭 1 |  반복 1021 / 9295 | 시간 117[s] | 손실 2.55
# | 에폭 1 |  반복 1041 / 9295 | 시간 120[s] | 손실 2.57
# | 에폭 1 |  반복 1061 / 9295 | 시간 122[s] | 손실 2.57
# | 에폭 1 |  반복 1081 / 9295 | 시간 124[s] | 손실 2.54
# | 에폭 1 |  반복 1101 / 9295 | 시간 126[s] | 손실 2.54
# | 에폭 1 |  반복 1121 / 9295 | 시간 129[s] | 손실 2.53
# | 에폭 1 |  반복 1141 / 9295 | 시간 131[s] | 손실 2.52
# | 에폭 1 |  반복 1161 / 9295 | 시간 133[s] | 손실 2.56
# | 에폭 1 |  반복 1181 / 9295 | 시간 135[s] | 손실 2.53
# | 에폭 1 |  반복 1201 / 9295 | 시간 138[s] | 손실 2.52
# | 에폭 1 |  반복 1221 / 9295 | 시간 140[s] | 손실 2.55
# | 에폭 1 |  반복 1241 / 9295 | 시간 142[s] | 손실 2.51
# | 에폭 1 |  반복 1261 / 9295 | 시간 145[s] | 손실 2.53
# | 에폭 1 |  반복 1281 / 9295 | 시간 147[s] | 손실 2.55
# | 에폭 1 |  반복 1301 / 9295 | 시간 149[s] | 손실 2.54
# | 에폭 1 |  반복 1321 / 9295 | 시간 151[s] | 손실 2.53
# | 에폭 1 |  반복 1341 / 9295 | 시간 154[s] | 손실 2.54
# | 에폭 1 |  반복 1361 / 9295 | 시간 156[s] | 손실 2.54
# | 에폭 1 |  반복 1381 / 9295 | 시간 158[s] | 손실 2.51
# | 에폭 1 |  반복 1401 / 9295 | 시간 161[s] | 손실 2.55
# | 에폭 1 |  반복 1421 / 9295 | 시간 163[s] | 손실 2.54
# | 에폭 1 |  반복 1441 / 9295 | 시간 165[s] | 손실 2.50
# | 에폭 1 |  반복 1461 / 9295 | 시간 168[s] | 손실 2.51
# | 에폭 1 |  반복 1481 / 9295 | 시간 170[s] | 손실 2.50
# | 에폭 1 |  반복 1501 / 9295 | 시간 172[s] | 손실 2.54
# | 에폭 1 |  반복 1521 / 9295 | 시간 174[s] | 손실 2.52
# | 에폭 1 |  반복 1541 / 9295 | 시간 177[s] | 손실 2.48
# | 에폭 1 |  반복 1561 / 9295 | 시간 179[s] | 손실 2.51
# | 에폭 1 |  반복 1581 / 9295 | 시간 181[s] | 손실 2.53
# | 에폭 1 |  반복 1601 / 9295 | 시간 184[s] | 손실 2.51
# | 에폭 1 |  반복 1621 / 9295 | 시간 186[s] | 손실 2.49
# | 에폭 1 |  반복 1641 / 9295 | 시간 188[s] | 손실 2.51
# | 에폭 1 |  반복 1661 / 9295 | 시간 190[s] | 손실 2.47
# | 에폭 1 |  반복 1681 / 9295 | 시간 193[s] | 손실 2.51
# | 에폭 1 |  반복 1701 / 9295 | 시간 195[s] | 손실 2.51
# | 에폭 1 |  반복 1721 / 9295 | 시간 197[s] | 손실 2.51
# | 에폭 1 |  반복 1741 / 9295 | 시간 200[s] | 손실 2.49
# | 에폭 1 |  반복 1761 / 9295 | 시간 202[s] | 손실 2.50
# | 에폭 1 |  반복 1781 / 9295 | 시간 204[s] | 손실 2.50
# | 에폭 1 |  반복 1801 / 9295 | 시간 207[s] | 손실 2.48
# | 에폭 1 |  반복 1821 / 9295 | 시간 209[s] | 손실 2.50
# | 에폭 1 |  반복 1841 / 9295 | 시간 211[s] | 손실 2.50
# | 에폭 1 |  반복 1861 / 9295 | 시간 214[s] | 손실 2.48
# | 에폭 1 |  반복 1881 / 9295 | 시간 216[s] | 손실 2.51
# | 에폭 1 |  반복 1901 / 9295 | 시간 218[s] | 손실 2.51
# | 에폭 1 |  반복 1921 / 9295 | 시간 221[s] | 손실 2.51
# | 에폭 1 |  반복 1941 / 9295 | 시간 223[s] | 손실 2.49
# | 에폭 1 |  반복 1961 / 9295 | 시간 225[s] | 손실 2.49
# | 에폭 1 |  반복 1981 / 9295 | 시간 227[s] | 손실 2.50
# | 에폭 1 |  반복 2001 / 9295 | 시간 230[s] | 손실 2.48
# | 에폭 1 |  반복 2021 / 9295 | 시간 232[s] | 손실 2.49
# | 에폭 1 |  반복 2041 / 9295 | 시간 234[s] | 손실 2.47
# | 에폭 1 |  반복 2061 / 9295 | 시간 237[s] | 손실 2.52
# | 에폭 1 |  반복 2081 / 9295 | 시간 239[s] | 손실 2.50
# | 에폭 1 |  반복 2101 / 9295 | 시간 241[s] | 손실 2.49
# | 에폭 1 |  반복 2121 / 9295 | 시간 243[s] | 손실 2.49
# | 에폭 1 |  반복 2141 / 9295 | 시간 246[s] | 손실 2.49
# | 에폭 1 |  반복 2161 / 9295 | 시간 248[s] | 손실 2.48
# | 에폭 1 |  반복 2181 / 9295 | 시간 250[s] | 손실 2.49
# | 에폭 1 |  반복 2201 / 9295 | 시간 253[s] | 손실 2.48
# | 에폭 1 |  반복 2221 / 9295 | 시간 255[s] | 손실 2.50
# | 에폭 1 |  반복 2241 / 9295 | 시간 257[s] | 손실 2.47
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-5ff047ac089d> in <module>()
#      38
#      39 # 학습 시작
# ---> 40 trainer.fit(contexts, target, max_epoch, batch_size)
#      41 trainer.plot()
#      42
#
# ~\Desktop\deep-learning-from-scratch-2-master\common\trainer.py in fit(self, x, t, max_epoch, batch_size, max_grad, eval_interval)
#      37
#      38                 # 기울기 구해 매개변수 갱신
# ---> 39                 loss = model.forward(batch_x, batch_t)
#      40                 model.backward()
#      41                 params, grads = remove_duplicate(model.params, model.grads)  # 공유된 가중치를 하나로 모음
#
# ~\Desktop\deep-learning-from-scratch-2-master\ch04\cbow.py in forward(self, contexts, target)
#      37             h += layer.forward(contexts[:, i])
#      38         h *= 1 / len(self.in_layers)
# ---> 39         loss = self.ns_loss.forward(h, target)
#      40         return loss
#      41
#
# ~\Desktop\deep-learning-from-scratch-2-master\ch04\negative_sampling_layer.py in forward(self, h, target)
#      86     def forward(self, h, target):
#      87         batch_size = target.shape[0]
# ---> 88         negative_sample = self.sampler.get_negative_sample(target)
#      89
#      90         # 긍정적 예 순전파
#
# ~\Desktop\deep-learning-from-scratch-2-master\ch04\negative_sampling_layer.py in get_negative_sample(self, target)
#      62                 p[target_idx] = 0
#      63                 p /= p.sum()
# ---> 64                 negative_sample[i, :] = np.random.choice(self.vocab_size, size=self.sample_size, replace=False, p=p)
#      65         else:
#      66             # GPU(cupy）로 계산할 때는 속도를 우선한다.
#
# mtrand.pyx in mtrand.RandomState.choice()
#
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py in cumsum(a, axis, dtype, out)
#    2090
#    2091
# -> 2092 def cumsum(a, axis=None, dtype=None, out=None):
#    2093     """
#    2094     Return the cumulative sum of the elements along a given axis.
#
# KeyboardInterrupt:

# %%
# coding: utf-8
import sys
sys.path.append('..')
from common.util import most_similar, analogy
import pickle


pkl_file = 'ch04/cbow_params.pkl'
# pkl_file = 'skipgram_params.pkl'

with open(pkl_file, 'rb') as f:
    params = pickle.load(f)
    word_vecs = params['word_vecs']
    word_to_id = params['word_to_id']
    id_to_word = params['id_to_word']

# 가장 비슷한(most similar) 단어 뽑기
querys = ['you', 'year', 'car', 'toyota']
for query in querys:
    most_similar(query, word_to_id, id_to_word, word_vecs, top=5)
# Out:
# [query] you
#  we: 0.6103515625
#  someone: 0.59130859375
#  i: 0.55419921875
#  something: 0.48974609375
#  anyone: 0.47314453125
#
# [query] year
#  month: 0.71875
#  week: 0.65234375
#  spring: 0.62744140625
#  summer: 0.6259765625
#  decade: 0.603515625
#
# [query] car
#  luxury: 0.497314453125
#  arabia: 0.47802734375
#  auto: 0.47119140625
#  disk-drive: 0.450927734375
#  travel: 0.4091796875
#
# [query] toyota
#  ford: 0.55078125
#  instrumentation: 0.509765625
#  mazda: 0.49365234375
#  bethlehem: 0.47509765625
#  nissan: 0.474853515625

# %%
def analogy(a, b, c, word_to_id, id_to_word, word_matrix, top=5, answer=None):
    for word in (a, b, c):
        if word not in word_to_id:
            print('%s(을)를 찾을 수 없습니다.' % word)
            return

    print('\n[analogy] ' + a + ':' + b + ' = ' + c + ':?')
    a_vec, b_vec, c_vec = word_matrix[word_to_id[a]], word_matrix[word_to_id[b]], word_matrix[word_to_id[c]]
    query_vec = b_vec - a_vec + c_vec
    query_vec = normalize(query_vec)

    similarity = np.dot(word_matrix, query_vec)

    if answer is not None:
        print("==>" + answer + ":" + str(np.dot(word_matrix[word_to_id[answer]], query_vec)))

    count = 0
    for i in (-1 * similarity).argsort():
        if np.isnan(similarity[i]):
            continue
        if id_to_word[i] in (a, b, c):
            continue
        print(' {0}: {1}'.format(id_to_word[i], similarity[i]))

        count += 1
        if count >= top:
            return

# %%
# 유추(analogy) 작업
print('-'*50)
analogy('king', 'man', 'queen',  word_to_id, id_to_word, word_vecs)
analogy('take', 'took', 'go',  word_to_id, id_to_word, word_vecs)
analogy('car', 'cars', 'child',  word_to_id, id_to_word, word_vecs)
analogy('good', 'better', 'bad',  word_to_id, id_to_word, word_vecs)
# Out:
# --------------------------------------------------
#
# [analogy] king:man = queen:?
#  woman: 5.16015625
#  veto: 4.9296875
#  ounce: 4.69140625
#  earthquake: 4.6328125
#  successor: 4.609375
#
# [analogy] take:took = go:?
#  went: 4.55078125
#  points: 4.25
#  began: 4.09375
#  comes: 3.98046875
#  oct.: 3.90625
#
# [analogy] car:cars = child:?
#  children: 5.21875
#  average: 4.7265625
#  yield: 4.20703125
#  cattle: 4.1875
#  priced: 4.1796875
#
# [analogy] good:better = bad:?
#  more: 6.6484375
#  less: 6.0625
#  rather: 5.21875
#  slower: 4.734375
#  greater: 4.671875
