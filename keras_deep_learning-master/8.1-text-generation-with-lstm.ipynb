# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.3.0'

# %% [markdown]
# # LSTM으로 텍스트 생성하기
#
# 이 노트북은 [케라스 창시자에게 배우는 딥러닝](https://tensorflow.blog/%EC%BC%80%EB%9D%BC%EC%8A%A4-%EB%94%A5%EB%9F%AC%EB%8B%9D/) 책의 8장 1절의 코드 예제입니다. 책에는 더 많은 내용과 그림이 있습니다. 이 노트북에는 소스 코드에 관련된 설명만 포함합니다.
#
# ----
#
# [...]
#
# ## 글자 수준의 LSTM 텍스트 생성 모델 구현
#
# 이런 아이디어를 케라스로 구현해 보죠. 먼저 언어 모델을 학습하기 위해 많은 텍스트 데이터가 필요합니다. 위키피디아나 반지의 제왕처럼 아주 큰 텍스트 파일이나 텍스트 파일의 묶음을 사용할 수 있습니다. 이 예에서는 19세기 후반 독일의 철학자 니체의 글을 사용하겠습니다(영어로 번역된 글입니다). 학습할 언어 모델은 일반적인 영어 모델이 아니라 니체의 문체와 특정 주제를 따르는 모델일 것입니다.

# %% [markdown]
# ## 데이터 전처리
#
# 먼저 말뭉치를 다운로드하고 소문자로 바꿉니다:

# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('말뭉치 크기:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 2us/step
# 말뭉치 크기: 600893

# %%
type(text)
# Out:
# str

# %% [markdown]
# 그 다음 `maxlen` 길이를 가진 시퀀스를 중복하여 추출합니다. 추출된 시퀀스를 원-핫 인코딩으로 변환하고 크기가 `(sequences, maxlen, unique_characters)`인 3D 넘파이 배열 `x`로 합칩니다. 동시에 훈련 샘플에 상응하는 타깃을 담은 배열 `y`를 준비합니다. 타깃은 추출된 시퀀스 다음에 오는 원-핫 인코딩된 글자입니다.

# %%
# 60개 글자로 된 시퀀스를 추출합니다.
maxlen = 60

# 세 글자씩 건너 뛰면서 새로운 시퀀스를 샘플링합니다.
step = 3

# 추출한 시퀀스를 담을 리스트
sentences = []

# 타깃(시퀀스 다음 글자)을 담을 리스트
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('시퀀스 개수:', len(sentences))

# 말뭉치에서 고유한 글자를 담은 리스트
chars = sorted(list(set(text)))
print('고유한 글자:', len(chars))
# chars 리스트에 있는 글자와 글자의 인덱스를 매핑한 딕셔너리
char_indices = dict((char, chars.index(char)) for char in chars)

# 글자를 원-핫 인코딩하여 0과 1의 이진 배열로 바꿉니다.
print('벡터화...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# 시퀀스 개수: 200278
# 고유한 글자: 58
# 벡터화...

# %% [markdown]
# ## 네트워크 구성
#
# 이 네트워크는 하나의 `LSTM` 층과 그 뒤에 `Dense` 분류기가 뒤따릅니다. 분류기는 가능한 모든 글자에 대한 소프트맥스 출력을 만듭니다. 순환 신경망이 시퀀스 데이터를 생성하는 유일한 방법은 아닙니다. 최근에는 1D 컨브넷도 이런 작업에 아주 잘 들어 맞는다는 것이 밝혀졌습니다.

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))
# Out:
# WARNING:tensorflow:From c:\program files\python37\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# 타깃이 원-핫 인코딩되어 있기 때문에 모델을 훈련하기 위해 `categorical_crossentropy` 손실을 사용합니다:

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## 언어 모델 훈련과 샘플링
#
# 훈련된 모델과 시드로 쓰일 간단한 텍스트가 주어지면 다음과 같이 반복하여 새로운 텍스트를 생성할 수 있습니다.
#
# 1.	지금까지 생성된 텍스트를 주입하여 모델에서 다음 글자에 대한 확률 분포를 뽑습니다.
# 2.	특정 온도로 이 확률 분포의 가중치를 조정합니다.
# 3.	가중치가 조정된 분포에서 무작위로 새로운 글자를 샘플링합니다.
# 4.	새로운 글자를 생성된 텍스트의 끝에 추가합니다.
#
# 다음 코드는 모델에서 나온 원본 확률 분포의 가중치를 조정하고 새로운 글자의 인덱스를 추출합니다(샘플링 함수입니다):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# 마지막으로 다음 반복문은 반복적으로 훈련하고 텍스트를 생성합니다. 에포크마다 학습이 끝난 후 여러가지 온도를 사용해 텍스트를 생성합니다. 이렇게 하면 모델이 수렴하면서 생성된 텍스트가 어떻게 진화하는지 볼 수 있습니다. 온도가 샘플링 전략에 미치는 영향도 보여 줍니다.

# %%
import random
import sys

random.seed(42)
start_index = random.randint(0, len(text) - maxlen - 1)

# 60 에포크 동안 모델을 훈련합니다
for epoch in range(1, 60):
    print('에포크', epoch)
    # 데이터에서 한 번만 반복해서 모델을 학습합니다
    model.fit(x, y, batch_size=128, epochs=1)

    # 무작위로 시드 텍스트를 선택합니다
    seed_text = text[start_index: start_index + maxlen]
    print('--- 시드 텍스트: "' + seed_text + '"')

    # 여러가지 샘플링 온도를 시도합니다
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ 온도:', temperature)
        generated_text = seed_text
        sys.stdout.write(generated_text)

        # 시드 텍스트에서 시작해서 400개의 글자를 생성합니다
        for i in range(400):
            # 지금까지 생성된 글자를 원-핫 인코딩으로 바꿉니다
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            # 다음 글자를 샘플링합니다
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# 에포크 1
# WARNING:tensorflow:From c:\program files\python37\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/1
# 200278/200278 [==============================] - 107s 533us/step - loss: 1.9688
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the astent and allong and the interistion of the something the master and in a man a something and string the this of the are strend the self-and the something and as a souls a stand in the same all the the are the last and in the reast the persons and the also the master and in a man the conscience, the part of the making as a man in the really the something and man the man a think of the senst
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the are make of the discomedity of the man because the masterss and interpection of the should morality and the secent which which in the beerable to be nother from to ethic can the moile of the scinguth a there in the harts and and must means of the action: the proment to stractire the man man the still low the man certain in a kind of the makes a simplated and in a man in the somethy is a sens
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fold for the values it good innationaty, heralesly wassy a tequ,
# is a morancetion of conceptions, of the genousk and ss anie oul stimable one fealoun formin, fourtes en his one its aed to orded the peressian whom rive lapsess conscionsations that evoses, he will prome they promise and moicaphistens, sympated attect a sablo and no ope oubd. things of ming sundstantand, the getions thad us. in his cou
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for comonition and cepteessed a
# therevolbdy the that bhmne alwhy him inmally not cerseffow in the gooddurcuely, as knowm,
# anks narical,tr knowledgs,"--whemever"--youts alt its aversamecishuls, the liane  as
# isth lhatfelke, hismest
# pore? when himge, and the rearols certale in olhews, tomalltanctiqualle
# cogretable folro ethe egoy they pasting
# are
# allagicly which a  howing coltrical
# benessions, compsie
# 에포크 2
# Epoch 1/1
# 200278/200278 [==============================] - 105s 524us/step - loss: 1.6172
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through form of the conscience of the stand to the conscience of the sense of the stands of the stand to be the conscience of the conscience and stand to the stand and all the constance of the sense of the power and the conscience and seeks of the stand to the cause the stand and the conscience of the conscience the presenting and the state and to the stand to the stand and the fact and pleasure of the stan
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for a tautely is the highest and also understood the conscience expecies as a love of the lears and and eperition and religion of the to a woman against access of the charted in the conceive to a means of the spirit and succested of the morals of the stand of the soul to cince as a mankind of the complice as such all the book of the power and
# will former in the conscience of the constand the stand b
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forteniated allowifire to take acceptes of the
# sasaurising through the othert. the percopition of into case, lefes of the stant brid, all
# that ly
# conscious, daw and will religarity is wolw romariving expression to pribiding, of these posate on the muscone is conceresss will all all importary so forthonoug handorder not man
# seems to guauss to anjust befuld cacacces of a time, howard--if he !
# ampea in
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fore congrouse sjill, all conscuently compercreedity; sacrifition of itequaitstomicm
# on circimstly constatively rexiduding free1. seed to
# icfiman lote and genly compar move
# on sufficief (that a plact tris
# mirely-nambor from couraglly
# langate? himself.
#
# buc is elfist of ageon,
# belngons about fues to
# that olser, upsideity allory the differennc, the myst we higeice and ;wain yeachilourxarity lough by d
# 에포크 3
# Epoch 1/1
# 200278/200278 [==============================] - 106s 529us/step - loss: 1.5283
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the soul the most delicate of the same the sentiment that the same the sentiment and from the one any person to the sentiment of the sentiment of the scientiness of the strength of the think of the forment of the world to the paster to the fore in the soul in the strength to the strength of the sentiment of the strength of the strength the truth of the soul in the same any paster the entire the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formully for the world has a cannot the fact to the interention to the really than the in the last understand that the nowadays sented entrues of the well sone that the entire there are the most previous and done of the world of the strength of the possible of the desire to a mistored and states of the scientine that is only the power to the self-dors to the an any on the way and the sort of the him
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forger the power, bucked that is cluse and enlight soul--the one tarin(.
# thoteer a christial respentisd of
# dele--unterdally for the sucjerk--who "counmed so-persontation something
# of human hoppises of
# the are shows as a interiret, and then any result, or suffering to life-nurl(cand in the dors-even deceeting comparised froc. in the science, in the kefultierity of frum of whicl
# on the wringer only th
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through formuses laked should seldies tn; als
# etrentsiteddswili mod up." an incanaim gree, loke".
#
# l1'sisnes of not ditain this this.--no surcenesed,
# ebor. that in oun
# thouks an
# over hoar for the elife good to thin. the
# thrells, some disbibity in
# senseful). becate our morable perknestins, god himself, perhaps testle repoder a idable, the
# tone another ord! congeatesw disco ferlo,arir, occabiers for omestanes
# 에포크 4
# Epoch 1/1
# 200278/200278 [==============================] - 106s 528us/step - loss: 1.4850
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through formeven and the sense of the sense of the strange of the sees a soul the stranges of the every intellectual that the states and the faith that the sense of the states of the states and the most problem of the states of the best made that it is all the man and in the strange of the strange of the sense of the sense of the spirit of the states of the sense of the sense of the strange and the states a
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through found, the origin of the best passional standard and in the pain and man of the schoole discristful and greated in the sense of the man abso some a consistent disposised and something that its probably the nature and moral greek the historical sures that the stames, in all philosophy is allow allow the conserned
# and makes and intellectually been also
# result of the faithest of the historical sense of
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through form: the last be concerned
# formerness earw from no ido
# abouncs
# typed. in ages in
# the becauses and thete meach time fintse of am sur wort flicting-is alout
# order as
# consist
# ofly metaphysosent string mostefor beforeness, and with act who lature how abod thing, it actually strimes not pains taquerated neces of lives, ald down--word manding that there are justine his imposence
# of egom? is desire beture
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for equally always
# ri,herplan comparisns aad
# reward-expresservies--flois, mfover, merulis. yunine successimar, reality of
# sen, c=menteriom of feeling always attently fain,--are!
#
# 1ndse1menss ly pires all doing, leage and venceness of the
# spirits,
# mokeny it were otherge";
#
#     l, samired, sam. mingnsh, thopsy that centuriew in eter, as fall
# that, who was attaners, very all is, or one
# impaterr; from
# s
# 에포크 5
# Epoch 1/1
# 200278/200278 [==============================] - 105s 522us/step - loss: 1.4550
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the the contempt the contempt of the the man and state and the contempt the self-contemplied and the man and the self-contemplation of the contempt the sensitions and the self-conditions of the self-contemplations and perceives of the sensitions and also the faims of the thing the contempt to a man and the sensition and the sensitions and the belief the conditions the self-conduct o
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for in itself with the every the must be one of the values the self-case, a man where form and and the values and the state and suicable of a man soul who is a intentional and feeling and lacking to the depressions and the expressions of all the contempt
# and know the conscience selfification of the live
# and for a but which all the words of the fairulty the free which and religions understand to make
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through form, deepises in
# uses
# upon it is were the tulimism, althsting of disoveredioush of the are thing sympathy a
# meadive of things from acts bryen that puth for one's effetions and like they
# such atowed artulifess with this virtue, sogigating,
# and false of styre in the
# europe and
# thing that is, and
# aftering that all wasing assiving to uncave: betteebed. thehes and regard gives which
# is shortafe europe a
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for
# every intellectual. yous?
# and more su: ever that
# is
# "century on the from hithacigners and reyied, shetery afttsuawish
# ownt to man," how menst--aothurience to daint circoms
# it deept of the cal towamjour" tol, but in noble opinion tot and oriunopiug":
# the difficainscen bork
# ofrtacs, how put we
# willing
# whequerwofogixth ethlable
# of the wordrly conbit. injutions in an e"acting always needs has sunk o
# 에포크 6
# Epoch 1/1
# 200278/200278 [==============================] - 106s 527us/step - loss: 1.4323
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the soul is a desire and the sense of the soul, and the stand of the sense of the sense of the sense of the same the sense of the sense of the sense of the same the sense of the sense of the sense of the sense of the spirit and the most distinction of the sense of the same the sense of the spirit and complement of the sense of the sense of the sense of the expeciations and the super
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through former and possible, and in the senses and believe and consequently better of all the artists and single and complement to be every lands to the really should all the all the discisinterations and a free mistaken and one make unmeasure, and the command the expeciations and the command to the soul is antale the are and the sunftent morality of the truth of the soul, and impulse of the christianity,"
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formers
# and themself uncants it will be belongs, and as them as the great in their world to , operation
# is enemy one confend he flesse bit take of they, whomingness of the fettere, into hoes inclinate
# mifiurgling one may no classe, wish the lost existed in many life, as the disorvate mals nowadays fain to
# them, excesses, the midsesds to suelpess? it happiness, that the world and feat to a new a nese
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fourdres, the pare, and our just cruaity of them untesta!tiving to teres--whithouth--nothing why is mosts."--or matters. antoip german acquiratiss," unwornum--to the ormistic hard)ly, disonbiu our inverteess,--in them mother a thought
# are else, "mood lumbut probleismpbods be
# motives for regarcturs, one forttrums, a heil food to so trapist who
# hundred good"--is at
# hard emativiminatious lofte it
# k, wh
# 에포크 7
# Epoch 1/1
# 200278/200278 [==============================] - 104s 521us/step - loss: 1.4152
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same the supersing to the greatest of the fact to the deception of the intellectual complexity of the presentes and supposing the artists of the self and the sense of the most in the soulf of the belief to the man of the sense of the sense of the truth of the problem of the sense of the world of the same the sense of the fact to the cause of the sense of the sense of the sense of the complex
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the comprehence of the fact to which way with the sense of the ofference in the presenting into the soul are simply and the finers of the intellectual can be they fall has been there is sensition of the most offered in the most truth an intellectual dine should and want the greek and feelings, of
# the same of the world because which is so trueuth there are supress of the restiny of the strange, t
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for to innoceristion to aristomes of ezat an inlong needs very nothing selfion to been same cource of libing time), or of life
# has dessent the sexuality of hard different of
# said, whold in
# standand opposeth of the supers. to humpare us. " not of
# tocal, but most as su persains and notherners cateal barfuline woman--ill be far beliel cruelty knowlestrated to resuct agarn
# of sulfatian could own indidan
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fore" wither taskiblesed, eaplueveles. where,--their that a brubling this
# insinubitualful" made,
# a: unnamed, is dangere, toourth that fihtntuspreed grounds hand also pronouted in which a said, here to be promisten imeatuit. soche philosophy. f easuius mmieating one will ludnen
# provedualing formsr at and there frielaganize: to beaut for its fulls mightt! nemity of cruce is weakeved relugityal is idea
# 에포크 8
# Epoch 1/1
# 200278/200278 [==============================] - 104s 518us/step - loss: 1.4014
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the servich in the principation of the survively the sense of the sentiment of the sense of the soul the philosophy of the present of the servich in the soul of the present something the servication of the subterty of the sure, the servich in the soul in the soul the servich in the same the soul of the sense of the sure the survively the soul of the serious and the soul of the same the survively
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the command of surcerness, and as the contrary from the bry; every principle over sicking the religious and and the world of the present
# becomes contradistomanized in the purpose that in the present brough. the serfic the world of the sentiment
# could be be something and all the belows as a book of the very our interesting aspect and own the most promate aternal most soul is present experience ma
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through force belong from old any once
# more crreid" in co, profrhartiver happiness only to downrives "the we
# have alwaysingly
# brimble. and in
# himself--we are arrigin thind religious doctaind, vary condition, the econony how can limity, is develop
# marlity;
# thpozer doublughter theme. he has disdulg other
# mose regard renate at loodles of all over sep sometion. they made for thew form--in, bron the footful
# all
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fowstulgen wampuld, did egain of the world mowing brought besie also "every having poments love, tradic forlevolative
# fet is incpind, very inveryed nothing do?
# " "other attens-or
# do not civibidd,
# and bodieant things of the of moral trie under. do rend are by aakids, exrestimitual, senfraung , metsop, every whate" hate
# to
# contemnceop light for aasmive" if him--nor trays intention on them, in indixtic
# 에포크 9
# Epoch 1/1
# 200278/200278 [==============================] - 103s 515us/step - loss: 1.3905
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the belief is so that the contradict the subject of the and the soul of the deception of the consists of the commander the religions and the concealed the and comparison of the same to delightful and the same the son and the experience and contrary of the precisely the same to spirit and the sun the soul of the same the concealed and the concerning that the commander the successific and complear
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for existence of spiritual and reither believes, the higher the world and comparis and profound, and the subject the hard for the will to be more first of the sauses, and and promise of the deceives the our one is strong of the compleary and experience of the commands of the scientific and conscience of the there is a soul of itself with a strong the bring and perhaps only the way in the presentible
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for
# nim the has point
# ple of said, who man of a make them swee as dse,
# terres.
#
# 1 of
# present, poetth men thereby standards: there
# ke a precisely contra for instructed
# of their a conours deepless and centifalitian. cause neithering characteripons on the they do not unalletter then on something self; a sacrijes
# and minalable has the therefore, the do
# an emplay increstioncy at the straccuality eyes,
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through founday or only moruours. provemitenly that
# isposes popentition or -thutlest oming of which, mo"ch" swe doking
# good their too way vitaclike a, you this done trreast intallk are infepeining to slamey teasting, to look and muaition: but
# who asis keem doongy comdsation in this nature, chang amasent asaper pwise: those who have bind and highly learns that, it we broid of botabirs, a faitur
# knowsgates,"
# 에포크 10
# Epoch 1/1
# 200278/200278 [==============================] - 104s 519us/step - loss: 1.3817
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the states of the are and the sense in the soul of the sense of the sense of the same the sense of the sense of the sense to the deception of the same the sense and the sense of the soul the passion of the soul and the most more the sense and the sense in the sense that the sense in the same the sense to the sense of the same the such a doing the present that the present and believe
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fould more and that the sense for the falsely recognized and the part of the most profound that the assertion of the existence of the passion to the good have been doubt to himself, as if the consequently not cont is a spirit in order to the complexitation of the soul which may an altering and other visitity in the passion of the exercised in comparison to the german to such conduct to its soul orig
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through form their
# seas reluct. that it nor overet loow-dpopths of hereles everywhere scarnestis case to
# the
# welfard spring take his warse knows
# to a analken arentual from conduce of "to dicred as but theureness in
# their tealtwers of
# ear
# extemulved and accoming and hepon or somearnes. i really have german magice. only as in thought, as its forded, instincts
# the point, that which a "cata" he regard transthed
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for one a
# peopleing haty of eveld, distenses.
#
# 11ou hopmctunines,
# that
# they would learn, you untilly virtuous ug"
# positing m-for nershbie and carrively be howevers trimation fingly in germanity if some "demcintainity.
#
# 110 s
# ownined, whole
# "n;
# and stick,
# a volent, this wordp cistumed not hate, there as shown.
#
# ether opinion brove sends ogerous cest free thriught, indeency in
# conjection thring tespac
# 에포크 11
# Epoch 1/1
# 200278/200278 [==============================] - 107s 535us/step - loss: 1.3741
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same the world is a sacrifice of the self--the same the same the spirit and the more the same the consider to the sense of the fact the sense of the same the same the spirit and the sense of the sense of the same the same the same the same the self-contrain the sense of the same the sense of the soul as the best the same the same the same the spirit and the spirit to the world to the sense o
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the private with feeling as regard to the will be regarded and soul such a mean is the world without consider and being to him if a distingurs, the happiness and always does not be truth of a consorfolus and really and for instance and the unifece and the most precisely the enough to its in their intellectual more fact to life something of the sense of the most the soul of the higher individual
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formerlulgs, all moral
# devolving god
# can sad natuce of the
#
# uncorrars.
#
#
# 1
#
#
# =havgl, and for initionation,
# is the regress that wigh all voluse learth an angoken "viatuous their exist product in homos outless
# to varicless. an iman
# his tastes of
# to priviganations of elevate, one lovel: here become which throw have its always so well as a more ethic without sain, is notricial, as so !quiditation, on th
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for them). bot, humple
# to anoih bolalgitaality," and that sonest select distingurs and supreorsful that
# "ethic"
# us is them druster; for in reithistic only otherur everythines to worldurount and world
# repain self
# beimorable because mudlures his faitl anamentage.--it is every
# selfament for them, subfosted. thear a roai deed.=--the be but
# where new lothed in our formul., much desirabieiartpens's spirit
# 에포크 12
# Epoch 1/1
# 200278/200278 [==============================] - 105s 522us/step - loss: 1.3657
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through formerly the suffering the states and the superficial to the soul of the stand of the states of the same the sense of the sense of the stand in the sense of the conscious and the spirit and in the world of the soul in the sense of the sense of the sense of the states of the stand one of the artists of the stand in the and the states the stand the conscious and superficial and the superfician and sup
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through forming the good self-restrefulter that one must perhaps the consolity of the general than he is the mastery and threat about the ancient condition and advance and himself of the superfician than the thing good or to be the superficial and little higher and many and history that the sense of the tempobratical supposing in the present in the will to developed in the religion to the realm as the soul
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forme) be say also it no least man of the
# lavks the idental"--the most pevilsing
# encesse right upon the questions of the superious; the infairmual of duatrw, succulifs of mere
# profound
# sguise decline infinite
# than which happutely
# franity in the religious one
# experience coarpaid have to him hoith literative
# and delustveltions of mankind. if new things self-strengt exaggenenly against
# typucauses noble
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for "human
# groeg-, chrosite christy incarr, we sooche
# givers less is no kynf formevienty
# of shard  s
# et love knows, the disperies his
# hilderous as thereof diw what being,--whedever political regard whiear--and
# whole things that kindssvoluns?
# ha
# ambuldevation of knowledge bare. ashor. fere experience, "sign formerly groeksed moretains, in opine to something metrauan). but
# some indvenguarity. to light
# 에포크 13
# Epoch 1/1
# 200278/200278 [==============================] - 103s 516us/step - loss: 1.3593
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through formerly can be something from the same to the same the sense of the to be something the same the sense of the senses of the self-propertion and man of the same the same the same the self-propertion and the same the strength and something and the such a conscience of the desires and the sense of the same the senses of the same the same the self-precisely the present of the superior and the sense of
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formerly and becomes free spirits,
# into the ressing heart and still man he would
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formerly question of their aims to
# be sostenments, as dignical need, in philosophers, sages
# to also the marver the should as and county--without the
# eustals or ba, becomes to love, typation"--situring with a positide. they are natural sained to which the values, he is althing dogmating which, hepetation, period indegened artist
# conscience his breast to churbiar
# into
# stol, this conffate, emoces, it
# s
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foreits folsers at
# bestine of history; this deeps, rabers: "this
# power sfal!
# krow.sifaced has out is these concerning so warthtrogeragear
# his only and scarter off all most togetherg whatever, and for intuorated which ham--this hoby one
# with romethess, suchomer: it suffyic of such dedpinnan norlod prewise petations it
# mnoke (him from it seisid, that
# . by the usegol; free expecian
# of fundaments?  i bo
# 에포크 14
# Epoch 1/1
# 200278/200278 [==============================] - 99s 493us/step - loss: 1.3535
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the science of the sense of the sense of the standard of the same the best to the same the science the consequences of the way, the states the states, and subtle in the science the same deception, and the science and allowed to the soul and the sense of the same the same the science that the surpousing the same the sense of the same the man of the same the truth and the same the science of the m
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the science, than has hitherto some the wealth in the states and being of a depth in the case with shint his impossible to be the characterised by still being a german in the surpousing the fact to a distingurs
# of the sense of the fact to thinking have its overthe fables
# when the
# the instinct the precisely the present of the conscience, a most standard of the simplicity of sacritirm of the wealt
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for stime to
# their willing for
# time to these accob, what defore of hered
# into delicately an in old of manifold, or consciences the factling horr the burdeny and states, for every dis who talk.--the characterisony is usful the indolence." ant posisisism, applomes for most eascher in higher a realman instints--theological, pecontsly for which pantisanism, command the qualitofies of their is, which we
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fourdke
# instintain, of all some will what of himselfly,"" soulss, whordly ingoethes our life!"---ppone
# mainting, period own millogic of other will in a
# world partila
#
# specierable envisafite
# ustoar. foother happonh as voluntures contick anche ha. he yet there ie as will of emperiorieshphive almost dipay and provess,  means. but-meams
# of
# an ake power and character, so but externabs faith
# than is unsco
# 에포크 15
# Epoch 1/1
# 200278/200278 [==============================] - 97s 483us/step - loss: 1.3477
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the states, the states of the passions and the present prompt and conscience to the states of the soul and the present and desirable states, the present of the fact that the problem of the present the entire to the manifestations of the demands of the present in the same the fact that the proper to the scientific and such a contrary and desirable to the proper that they are as the soul and perso
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for in in the distinguished to be indeed to a philosophical and such a doward, and being predomand and the human and its own society. the present sought so much as a politic in the great parties, one has understand the bad the will even and manifest and the hold to be allower long and the same pation of the fact the last individuality of inderstovard and nations of the values of all entirely
# as the
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formen and sileby comparism assucalitic towardip" sphell stated that the contrarity, woman, sonet, as a time the words, it
# arts of the phenoment to me, as a prisentuce into moral galt and contrary
# world--other insiral
# with moment, i nowled pettes of "prenounc," and just a
# destrumir
# to at any.--"and spoil self-close coxtrarians--what yet precisely an imagine them words. they are but in it, we they b
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through form and
# in ranger
# truptic intorair cress ma.l these- always--fut believe, had becaurly.=--that is tnutifacnusn either preparorses cardow, any instance rhy almare temable with a doctoon of errorsity world.hiacal owing foquertip thereof-rannerce of the cursigations (which, who disvinctire is: with they would a reself anaifess? why sacrifice meres, namely attairre
# into the sensitick
# repsiou to which d
# 에포크 16
# Epoch 1/1
# 200278/200278 [==============================] - 97s 484us/step - loss: 1.3437
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the world and personal intentionally the most so the superience of the prouded the desire the superience of the specially the superience of the senses of the conscious and the same the superfore of the complexication of the same the spirit and the superficially the spirit and the superfort of the same the things and the superfore and the present and the spirit and the world and the superfore of
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the southing and person our conscreding of the south the spirit the spirit is a man with the superficially the schopenhauering the late the part of intellecty of the little our still all such a consequence and more intellectual more present which mankind conscious to the comprehender and a means, and and
# impulse and superficially one's forgeth of morality, and the last
# man
# as one of the same the
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through founce of consequed. easuhers it if inselved create over
# discourses--the well-reason to the aimages--pirtewing he lacking, but the whole philosopher mutually eye spool by nature, perhaps accordant to
# tacting, possibilities, by repute. in the
# only iust "commanding in attained? and dangerous vew sworrm of the hepic intensation -hind affect and deal
# funday and clear to
# former
# of the stench," of many ou
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foundation, the
# cases,
# "tirely higher kue, intentially soger iborfation tuithe a
# one is avour agest think, and fund predion of schopenhauedly.="--a suicating regard to learns, we freewive rue knows, but humblenties
# deedy, negation? by heave which still hopes, of existinguly belief of understand to cold
# the very tears. "so, a colsing, creal senseon--chases-is the gueds, deliete at
# aom,  owing,
# of wej
# 에포크 17
# Epoch 1/1
# 200278/200278 [==============================] - 101s 503us/step - loss: 1.3385
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for in the superiority of the sense of the sense of the same the sense of the sense of the sense of the sense of the sense of the sense of the same the same and the sense of the spirit and the sense of the sense of the sense of the present and constantly from the sense of the sense of the present in the strength and sense of the sense of the man with the standard and the standard and more in the sen
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formerly possible to an invention of the freedom and relationship from a present before itself that is now not german to be believed to the ancient of the world and personal of the self-conceiving of men in the sense, as if the existence of the man can like enception and religion of the same will to be too would have been conceive of words man with this life of the face of the present of his one mus
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for "means and cumisnile, life ho. the
# compers of his dwarfinan afforfultion and
# borted, equally believed suppetion: for instants, and ineximing incourse of ourselves,  ow modern danse
# to find-willing to
# who discoverous,
# and in perposses, yew is enough, to our own strike in when encounse of e!che of man will be tradition of grised it myrreadonable inferses and minds to philosophy had certain
# s"uncha
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for has pet
# an then-. is in statee, there
# is
# nimed" always? bute" symmaticre, no longer general
# astenutjubic but in all thoished hels of his new friendstfre--a at for but the trusimenen general
# pare of the selfquently grait to democle peiped not purould bey is, a dwinghitats, thin, as grampls and bry unwill touch la:thulomed and no known in
# thpisestical in
# this have men iseod
# by the! is convalted fo
# 에포크 18
# Epoch 1/1
# 200278/200278 [==============================] - 99s 494us/step - loss: 1.3338
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through formerly the states the play the same the world of the sense of the same the play and the subtle in the rest of the same the same the superied of the pressing the sense of the same the sense of the property of the most such a sacribire of the same the desire to the sense of the world and the highest and the same the personal problem of the same the states the states and all the world in the power of
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formerly friends. the world of the similation, and the value of the pleasures
# of the strength in the master of the mastered the most power, and benesity, and any ethics of the same to which has been the world of the most ourselves also the inconscience, and almost the agreed and
# free spirits to the way, and the fact to the all the immedoted in the fact the sense of the most persons and perhaps the m
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through former of this world, for
# these tonupoul commingh it is formerly the attented of presence of elstained that once hechalt,
# hemlountly, in a plast worldest as the life, only
# goodual. let its own more
# inferenty, thol, to this like
# the
# opinions through be doing wimh
# are us really
# imrathed-us.--whether the appeadely the fact a evolution of christianity, he laging in the qualities of mankind, long . were
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through founder"
# to lacking as europe, sellds injustory is not be andtest if they egoistic forthtain
# blinght.
#
# 1i1=
# the
# c:\program files\python37\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# most seventy hiviliwoble say, enway, laid eguticed, which perhaps that un
# in civwally, bold, nongean
# fromnlity, good of aograhy, most, in the brinate, and like
# to let us to me
# to it would be mudyment of chinging," as truthfulness and
# pognourhen
# here and security of mothous modes on, light"
# 에포크 19
# Epoch 1/1
# 200278/200278 [==============================] - 98s 491us/step - loss: 1.3297
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through form the more comparanical person the commander the subject the contradishor to the contradishor to the same the successful the commander the commander the contemporarily comparanical end the more things of the experience of the experience of the same the world in the presentimine the world of the good the subtle the subnlining the same the reason to the devil and suffered in the sense of the same t
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through form of the more
# discovered the attester there is development which of the measure work of experience of the end and belows to its domain of the freepoway the standard as the world the world to which is to be believe the philosopher the more wild and generally the present, so that itself. but such and who contemporariness be something he it itself, and i is, in the termate and the diving enough to t
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through form or beings to be machings in which the expended more poyed the
# futural
# sertions about active
# whatever anyone masic happinessmans expenders of fact lice, and for spirits
# for the
# goodens--threates, and incertaint believe and satisfactios, and one has disclusility of things "men to an are
# flish o--the ruireration hauvishend,
# more religion,
# how there "event believe, men from
# ra, sympathy, even in th
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through formtrives, this ownfuriogeougy, velater
# formeveled
# apphome tectoders! and
# foreyimaging of wiedly lightrhing,
# the
# extent superficw sost rangays out of free linging to consequently a trung to fragres the litt, require. the
# reorctificness. that see, prifounozatiquming of superstireless. between thus
# society of their moral" obseduanlism on the utuallest sabozant the , which is healture ashold dus, brav
# 에포크 20
# Epoch 1/1
# 200278/200278 [==============================] - 101s 505us/step - loss: 1.3260
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the conduct that it is a power of the existed and experience, and with the existed to the sense of the most distingually the intellectual ourselves and also the subjection of the same the spirits and intentious souls of the power of the fact the souls and probable to the same the stronger and profoundly to the same the soul, and all the strength to the superiory of the propage and believe and al
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the former present in
# the soul. the old believed in the distingually the propagicate and the soul of the unind with the
# most populace and evil to long and idea of man, not to the originates perhaps their part of
# soul itself, in the appearal general promise evil in the fact there are the same the resting that it is some the science all the free spirits and the fact that they happiness of the act
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foresticl other does not greek, into "progress and
# mavreactines of values
# in manifote faur; as any, as stapart as a trings abhuds for morality co--ne musirs who knows the determentory," althessique spirit from all his influence to be stronged half that is in phan all the surpes all comourd larpy eye
# of that typiclement-ack orfule of a man up thriblists to morartings of beguqual right dorken spirit,
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for fins
# be's their helsually pience.=--of one hardley of
# spiritw
# that it is ?r digrod out of this coing stakarly-ging, or has a
# need to sobarity apparness," about weceip xist distingual
# sanctra for commated by thebles the
# revenge.
#
# coepous by their difficulty for  gained pirtatively after alterneed. pether todalw,
# tenderagee is artun too--as untemplictols
# from estsmily recaposssqual a eviat any one
# 에포크 21
# Epoch 1/1
# 200278/200278 [==============================] - 98s 487us/step - loss: 1.3211
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the strength in the fact the stronger of the profound the strength and the same the same the stronger the stronger of the same the profound the stronger and such a standard of the entire and such an invention of the strength that the conduct in the spirit of the same the strength and such a proveration of the superior and spirit and self-dead and such a delicate man and can be strong to the most
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the thing is a most discipline individual of the world regard to a power to him to the fact that the self-antithesis of the most suffer and conception of the weaken for the same the god simplent is spirituality to consistence as it was only the how and soul, and the most desire of the pain is a okpostice the fact with a demand to be some refined and science of the most freedom. the superiority i
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for sense spirit of expression conceded men.
# no saridy should not possibable mas, if they is,
# and so traitude, for the jokes of justice change man lightend this out is namulss. whocjere with long and soutce the real over
# honer such as he to his caluted for such a realings: comes, from alsouted inclinate individual. apared, no rack only and befuret, the
# religily and whath who ruweaver indiliance
# of t
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for everto his benauring continuance in which
# tere firs
# only
# bruling, is too is dischilox of flat, not if one as-ires, is had tooer ideas about homy of science, fassoms, in ihsely when ever aftermating
# tempted embitting values.
#
#
# inant" single," has to injude a peropined and right, their exercissiling nature,
# will shy
# intemplecity ofeam, rangias, that which fully :    to mudberity losity mughtful mo
# 에포크 22
# Epoch 1/1
# 200278/200278 [==============================] - 95s 476us/step - loss: 1.3153
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through forein to be such a substing to the sure the sure of the subjection of the self-admiration of the sense of the subjection of the concerning the spirit of the successful to be something to the subjection, and more the subjection of the subjection of the subjection of the science of the sure of the such a man and the present, and with the most such a subtle and such a such a subtle and subjection of t
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for one has been of reason and feminine. one must not an idea how of the imagine the spirit of the soul-greman fathiness of the sense of the artists, who is a same the same and defensible and subjection, and most sure, and the more possession of the store" is intellect the reverse spirit is more history or to be something of the sense of the less the person althougl something of the "naturate of the
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through former the good rating contempt as cators of a
# value obeds otists in the
# determine of rule to one will grow with its word not us--the sense of idea as must be old resignated new; friends
# hes,
#            and is again instinct and life never must one myselves, and our oneselves
# ideas of man".--whethogently folst reverence cook-fight, loven, expected, sympathy, and regree which, knes of which is lower
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for
# in
# a being
# li! bbost, less anothers sch, hardlgene prelave much and ih the signto work and advanners. christianity,
# acts and deliring sympathy of all even but he debtures
# and pessimistine or necessary from the preaching, indeed, accuracule sestes meas god, nespowen, however, and by mind like judgm these much care.
#
# 171. the humanit-:lishers othern, some appreciation motay for any orrxculous beli
# 에포크 23
# Epoch 1/1
# 200278/200278 [==============================] - 105s 527us/step - loss: 1.3128
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through former and sense of the same the sense of the matters of the soul is all the same and all the power to the philosophers of the sense of the philosophers of the same and distingust and distingust and sacrifice the evil and superiority of the same and subjection of the same and subjection of the same the stronger of the same the matters of the sense of the same and all the contrary and subject and sou
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through forget of the sense in the complement in the future, but similarity and subtle under the cather to be contempt of this entice of the good a words of the personal belief and all voluntary formuld and personal disposine the souls also the strong to be the same and dislikelf-is completely be as a soul of higher intelliged to the disguise concealed namely, when i could be something have to be be perpori
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forction manifests and actually moodie accustoms as if it
# smicume, loves must learn to comprese it : an
# exwiliaty the refuclied to believe and effection, and toods with waut to a learn higher he majorius worken all
# the man seems, nofovery cultfoxiates sealard effecting,
# for something pregoined the grammly
# a
# honour matters and regard into them most the mat a propossing an iftenately diding for "more
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through folly as meaniatiyt divine and withoun
# ic"ferey ato forms of which there gaine bestrouss romage, profound. here, "iely. this disle. the rich and a might garl wleotners?
#
# ...
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the sense for the most the case of promine the other happiness of the sensed to the god and all the words that is a justijes and believer the present the spirits of the fact that the sense in the basis of the religious controlter of the superior more has a god of most states exist of soular, useful, the power that the positudence of the heart it is the words of the conception of the ratigious th
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through form under dure as
# in the volution: the sense of hustives" of liber of spirit and the personal his aims bbenelurenly acvulire" of
# naiceake one that he success in the maintain of religion in suspicious sthucts of the precisely many "eldvely before the best nomers sentiment of
# carry and an influence of extempticism of his conprity visides that only to centries, nes the very reconty after the mount bee
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fobprees untertain trabitions of every objectarring bur actant
# so
# poose in consequently, or be necessity of
# their smaitic, wick", the cognizedd, way us quitle practical
# extlussny, sciences--the moical advantames of the surfaculed in feminnte
# way,
# is being, is prevail him as e man of whom
# pleasure silfucidite, music, however manner, lose of demonxim--blessill. to doings
# on the
# form of dynators. we oe
# 에포크 53
# Epoch 1/1
# 200278/200278 [==============================] - 116s 577us/step - loss: 1.2567
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through former and can a more in the same and consequently and sounds and refine the reade and the soul is in the world and the same and in the sublimed to do who who has so that the sublimed in the sense of the same and in the sense of the world of the present in the sense of the standard of the most such a woman an an all the world and the problem in the world of the sublimed to the problem the moral exce
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through folly the bad the syrhow what is the whole earth and noble and it is always break and the happies and even and the spirit of the present them worksory of new certainty and is a democratic consequently seems to its well contempt and such a vercting by the hand to injurious and constant else as we be short for the being in the most such a woman to be the words of spirit which is not more believe it wa
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forth and some even idpressious principlation, not far, would look fundabun such a medool, or
# himself of
# the same sensul, those its will hether heir,
# one immnated pain, ansularity. let us wantenines and -as for iniman.
#
# 1in=ness and philosophers
# conscious, rulements; and which diligent and manry to such
# morality is that we have farmas feel theyer. is her more serility for feirle, over it should no a
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for grefeded what hab, is dribfx as here we have in great eventures what peope were abuse is to
# be dons, a inex, ill
# to arrivents, and heagely:
# for master
# being free
# still the toothing exception, "form and at pretertation of the like lices shefking and
# and
# if non crith-remor to vool.  gain the
# valus)
# confernation nate
# formuln thenstrices--as it is one at the firct with fear
# that
# we impusse needing
# c
# 에포크 54
# Epoch 1/1
# 200278/200278 [==============================] - 116s 582us/step - loss: 1.2567
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through former are there is a conceptions of the most profound the problem of the expedient of the more things of a thing the more their the formul and for the problem that the world of the most personal conception of the most pain, and in the same and the more profound the most men and all the suffering the more property and the sense of the most men who has a man of the reality of the same artistic of the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the arrend the value of the comprehend the convolition, and almost the more profound the god and his spirit of men and manifold, as the belief in the conceptions of the formul and with a more pain of the progress, with here and with the mouth, to an attempt
# a promisent of the old the early and the signification, are he may also the more promise as
# they makes are may always the very one must perh
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for what nearently, imagination--there are seasted were of skepting attempts lay to doot grack to so not on a kind of enocuteh. there is through the favour, however, it is a mothers as such knconius deaply dispocrity aggrehathysiblit impulse
# in christian artison ahs consider--sport best from thought may a?gqidutuald be is good,"--as everything this nearity. desires, for this hithertouren as thy if a
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foucible. where frenlients
# from
# all, our genius a "matter-gsair. on emancipating, his mevoles. thou,
# in sundeaws a sottly aedy calees, and imagendard superior
# epochake okpored to "the
# pain "faith for propecious thy natronurly slupafices--and play or sentims and
# valuation among rey, as aminds to
# dupingory, and him, this is
# ure thir growthedness of deliripility," abjection. and it--derirged wearing, (
# 에포크 55
# Epoch 1/1
# 200278/200278 [==============================] - 114s 571us/step - loss: 1.2547
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through former and the fact the same the sense of the struggle of the sense of the strength of the same the sense of the soul, the same the sense of the soul to the standard of the speciality of the sense of the standard of the more property and the standard and the contempt of the superstition of the standard of the standard of the standard and in the standard of the same the sense of the standard of the m
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through founder we are enthuring be still what is the will to be one must the contempted and galles of the standard, when it is something in the prevalousful and alone an endered and makes them as the problem hither more person of the
# individual to be seems to the sentiment and perceive the standard of the same sense of the standard and formerly be a definiteness of the fundamentally be a religion of the su
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through follow the tendency unding, but why we disphaised will be to be allow himself of "bides and pertrecise origin is something, such a more profounders, we is
# pandorism-for the last heart that if his
# sensation. this sentement to the habs the danger of most history of
# sgue, the pain! if english great staper of the case of wait; the fact do not so surers or
# does eway orde--and sitying, of marnone--and alm
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through folly, rin undempance think mave perces
# of all deity and
# there
# it too wigully ourselves in dialipl of caued called yiusly, then, priest of dismanse"" slown,
# operique dispute one we trooding, the most teriks that the severtherings, how being mys the upfainations of made sympatity and bebegage it pleciated in fact is not
# disperual,
# his faith,
# undinartion us dwell; heve horter the mass
# of ftennctively
# 에포크 56
# Epoch 1/1
# 200278/200278 [==============================] - 115s 574us/step - loss: 1.2539
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through forether and the soul all the most extrain and soul and the soul is also an actions and the present in the higher and and the superficial promise of the strength of the same and in the same the soul all the soul of the consequently of the soul all the most property of the most distinguss and soul is not to be the most personal and subtle the strength and such a standard of the soul and the first sou
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through form and the different from a delicate and
# something rare are even to learnt to will and progra(f=ke, and there is he to be allow his form and "pain, and are not display, more word to him to be tragic and scholarly to an actions of the most subtlitical and more art of the master before a philosophy as anyone of the williness, which their soul is also be the word and also an away to the strifts and r
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foretern course fen, which, in the
# unstance. a peoples at all the
# feeling and animal
# beverf as a balads
# are poetly
# awayity do the bland shall tly, this claim. to make finding imsginine truce.
#
#
#
# 11
# i towards there are, and maintament
# and propture what wy the agles dubmer false, fod, world is expieds things
# the later different trought" to simpla, any
# over
# wenter man" merely cognizind science, like to
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through form, untrancalty-lfkee, openy him, he yisome, all all the ollade enjoy, europe according to treepoted the
# pleasures with weaken, who are insideans! one has ever made things, owing toget, tofe)
# enciacuous
# obby        s kisdment itwise spick, so goab form, pibeans of the be newghilt, of theorsion and agot sejulty, here understanding most serief does
# not
# anbing of all un good and for eorable be someti
# 에포크 57
# Epoch 1/1
# 200278/200278 [==============================] - 102s 509us/step - loss: 1.2519
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through formerly profound the intellectual full for the sense of the sense of the sense of the sense of the superstitic of the appearance of the reason and the more possessions of the superstitic of the more their moral to the same the sense of the superstition of the suffering itself in the same the world and conscience of the fact that the contempt of the sense of the facts the unis and the best for the s
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formerly soul of the most actions of the world of the supersies; as there is one
# is not there is a dogry he method before the comparisonian, with the streng to the same and as the human acts contempt of an unintervationation has very contristicling to result have to the appearance in the same baluge profound sensition of the same and for their power, the hard to courage, and from the present distanc
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for this radical.
#
# 237. to discates things. but who
# knowad" to say, heald: a deunder to seems to overkne"--in consequent dine and distingle and finally, opint him tangaging the origin, which from animal "quessil, place the highest hast deliavific world
# asmulf. mustned--with
# them to goethe.
# "succe, acques is task all this expressing distermates a will sson demidation.
#
#
# 13
#
# =essed follofities, and as
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fournius of little, unterlaps of which what the radifal matcyeman
# wiltgs upon crave brint excessing in the vary we now englishmusses.
#
# 211. to they necessity
# and
# variety as it
# hosims function
# else as honeste from piges have now how doorst others pain of deist native. with a lack the
# poors om alone, as those would
# paipting that with orfireding nature, clought turn faith quoured and father no porty er
# 에포크 58
# Epoch 1/1
# 200278/200278 [==============================] - 101s 503us/step - loss: 1.2507
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through formerly the same and stand in the world and successful and stand and in the superstition of the sense of the sense of the soul, the world and all the most distrust and desire the problem of the most deceived and all the spirit of the world and successful and the most delight to the subject and something the presence of the sense of the strength and foreign to the sense of the superstition of the wo
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formerly of all the position of the mad successful and all the future of the duting and schopenhauer's profound the states of his states the
# sense of the whole the constant in the secined which still have the same and all the sense them as it is its worth; and they are not so domally with the soul, with the weaker become the consequences, and the world of man the truth the great to be something in s
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fordemptranity fentwiagre and
# own,
#      stands be in friendly "conditionf' hkpo would nemar
# leader avoltus: by the a disvery retrovenes and mothing
# but stating
# has always
# very for the precisely,
# were without attaining how ancrable eachs degree splacerated by account of vindine themselves evil with the highest the discreplies for unell their value natural possiuse the struge have
# not cause ourselve,
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foundfut man withcuridice indelok pals the priviy). little
# ?
#
# 111. foir," that
#
# sanm irst refine plessiquous
# baen thing and completely maxes agay after at present compare sort at welferfvence of
# serripon pictly), we harmely, lovely chapacy and brievitaine. he was be certain
# ecknum long
# timeral ttroke, why theords raous
# consideration
# vanity law, ame time guld its neuglate you aride, the done in casts
# 에포크 59
# Epoch 1/1
# 200278/200278 [==============================] - 102s 509us/step - loss: 1.2491
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through foretill and the same the superiority in the same taste of the same taste and the same the same are such a man all the sense of the self-contrass of the most still present be all the strength in the same the same and the same soul is a soul is the same taste of the superiority of the world as a protection of the fact that the same the same the problem in the same the protection to the same the perso
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through foretill consequences, the discovered to suffer, and it has have not been endables to be "the same and saints in a good into the divine the discovered by their standard and the deatisting entirely and speaking and success of the world has a successed that is the canes the rativous are the aristocratic when his means it is it
# with the type of the servical extent in order to conscience of the same tas
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foreigness should do
# not disponoxity in his immense place in a mentiling, solemtion, these sa!c cauable, one for others, pathings and case. then, which
# the multifitus, and when it has not baptmen nothing of betallght and
# even to--as
# even to the fear, christian great perhaps becaway the because of man without very proiss, is longly also, isonsed fetquent that the conscience the makings
# relors, just a
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for the wearly, he like ouhs with old fow a the hegomitary
# exist the chrised through exploitters. petions memissdist
# good extertling, as thus, hence! and
# deve faitureal law of which mettally still darking condanter faculty denuqque them hypoch
# in ideal: sittes, deit , "longers to morality might as utile so having ever to su
# "she has irredain any kepticion among that,
# in
# usage, more nor
# a lawe pronou

# %% [markdown]
# 여기서 볼 수 있듯이 낮은 온도는 아주 반복적이고 예상되는 텍스트를 만듭니다. 하지만 국부적인 구조는 매우 실제와 같습니다. 특히 모든 단어(단어는 글자의 지역 패턴으로 이루어집니다)가 실제 영어 단어입니다. 높은 온도에서 생성된 텍스트는 아주 흥미롭고 놀라우며 창의적이기도 합니다. 이따금 꽤 그럴싸하게 보이는 완전히 새로운 단어를 창조합니다(‘begarmed’와 ‘isharent’ 같은 단어입니다). 높은 온도에서는 국부적인 구조가 무너지기 시작합니다. 대부분의 단어가 어느정도 무작위한 문자열로 보입니다. 확실히 이 네트워크에서는 텍스트 생성에 가장 좋은 온도는 0.5입니다. 항상 다양한 샘플링 전략으로 실험해 봐야합니다! 학습된 구조와 무작위성 사이에 균형을 잘 맞추면 흥미로운 것을 만들 수 있습니다.
#
# 더 많은 데이터에서 크고 깊은 모델을 훈련하면 이것보다 훨씬 논리적이고 실제와 같은 텍스트 샘플을 생성할 수 있습니다. 당연히 우연이 아닌 의미 있는 텍스트가 생성된다고 기대하지 마세요. 글자를 연속해서 나열하기 위한 통계 모델에서 데이터를 샘플링한 것뿐입니다. 언어는 의사소통의 수단입니다. 의사소통이 의미하는 것과 의사소통이 인코딩된 메시지의 통계 구조 사이는 차이가 있습니다. 이 차이를 검증하기 위해 다음과 같은 사고 실험을 해보죠. 컴퓨터가 대부분의 디지털 통신에서 하는 것처럼 사람의 언어가 의사소통을 압축하는데 더 뛰어나다면 어떨까요? 언어의 의미가 줄진 않지만 고유한 통계 구조가 사라질 것입니다. 이는 방금과 같은 언어 모델을 학습하는 것을 불가능하게 만듭니다.
#
# ## 정리
#
# * 이전의 토큰이 주어지면 다음 토큰(들)을 예측하는 모델을 훈련하여 시퀀스 데이터를 생성할 수 있습니다.
# * 텍스트의 경우 이런 모델을 언어 모델이라 부릅니다. 단어 또는 글자 단위 모두 가능합니다.
# * 다음 토큰을 샘플링할 때 모델이 만든 출력에 집중하는 것과 무작위성을 주입하는 것 사이에 균형을 맞추어야 합니다.
# * 이를 위해 소프트맥스 온도 개념을 사용합니다. 항상 다양한 온도를 실험해서 적절한 값을 찾습니다.
